# %%
import pandas as pd
#Setup the display options so that all the columns are displayed on the screen

pd.options.display.max_columns = 100

# %%
teams = ['BENGAL WARRIORS', 'BENGALURU BULLS', 'DABANG DELHI K.C.', 'GUJARAT FORTUNEGIANTS',
'HARYANA STEELERS', 'JAIPUR PINK PANTHERS','PATNA PIRATES', 'PUNERI PALTAN', 
'TAMIL THALAIVAS', 'TELUGU TITANS', 'U MUMBA','U.P. YODDHA']

# %%
cols = [0,1]
team_data  = pd.DataFrame()
for t in teams:
    td = pd.read_excel('ProKabbaddi_teamData.xlsx', sheet_name=t)
    td['Category'] = td.iloc[:, 0]+' - '+td.iloc[:, 1]
    td.drop(td.columns[cols],axis=1,inplace=True)
    
    td.set_index('Category',inplace= True)
    td_t = td.T
    td_t['Team'] = t 
    team_data = team_data.append(td_t)

# %%
team_data
# Out:
# Category OVERALL - MATCHES PLAYED OVERALL - WINS OVERALL - DRAWS  \
# OVERALL                       121             52              15
# SEASON 7                       16              9               3
# SEASON 6                       23             12               2
# SEASON 5                       24             11               6
# SEASON 4                       14              3               2
# SEASON 3                       16              9               0
# SEASON 2                       14              4               1
# SEASON 1                       14              4               1
# OVERALL                       122             57               7
# SEASON 7                       16              9               0
# SEASON 6                       24             15               2
# SEASON 5                       22              8               3
# SEASON 4                       14              5               1
# ...

# %%
"""
import urllib
import json
from pandas.io.json import json_normalize


response = urllib.request.urlopen('https://www.prokabaddi.com/sifeeds/kabaddi/live/json/62_match.json')
elevations = response.read()
data = json.loads(elevations)
"""

# %%
"""from urllib.request import Request, urlopen

                                                                                                                            

match_data  = pd.DataFrame()
match_data_cmb  = pd.DataFrame()
Total_Matches = 0
Total_missing_links = 0

for i in range (0,3000):
    try:
        #print('https://www.prokabaddi.com/sifeeds/kabaddi/live/json/'+str(i)+'_match.json')
        req = Request('https://www.prokabaddi.com/sifeeds/kabaddi/live/json/'+str(i)+'_match.json', headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})
        elevations = urlopen(req).read()
        #elevations = response.read()
        data = json.loads(elevations)
        match_data = match_data.append({'row_id': i, 'match_id': data['match_detail']['match_id'],
                                            'match_number': data['match_detail']['match_number'],
                                            'date': data['match_detail']['date'],
                                            'start_time': data['match_detail']['start_time'],
                                            
                                            'result_outcome': data['match_detail']['result']['outcome'] if data['match_detail']['result'] else None,
                                            'result_value': data['match_detail']['result']['value'] if data['match_detail']['result'] else None,
                                            'winning_team' : data['match_detail']['result']['winning_team'] if data['match_detail']['result'] else None,
                                                
                                            'player_of_the_match_id' : data['match_detail']['player_of_the_match'][0]['id']  if data['match_detail']['player_of_the_match'] else None,
                                            'player_of_the_match_name'  :  data['match_detail']['player_of_the_match'][0]['value'] if data['match_detail']['player_of_the_match'] else None,
                                            'series_id' : data['match_detail']['series']['id'],
                                            'status_id' : data['match_detail']['status_id'],
                                            'status' : data['match_detail']['status'],
                                            'toss_winner'  : data['match_detail']['toss']['winner'],
                                            'toss_selection' : data['match_detail']['toss']['selection'],
                                            'venue_id'  : data['match_detail']['venue']['id'],
                                            'venue_name'  : data['match_detail']['venue']['name']                                           
                                           },ignore_index=True)
        #print("Data added successfully")
        Total_Matches +=1
        
    except urllib.error.HTTPError as err:
        Total_missing_links +=1
        

    
    
print('Total Data available for {} matched'.format(Total_Matches))
print('Total deadlinks : {} '.format(Total_missing_links))

"""
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ...

# %%
from urllib.request import Request, urlopen
import urllib

                                                                                                                            

match_data  = pd.DataFrame()
match_data_cmb  = pd.DataFrame()
squad_details =  pd.DataFrame()
team_stats=  pd.DataFrame()
Total_Matches = 0

for i in range (0,3000):
    try:
        print('https://www.prokabaddi.com/sifeeds/kabaddi/live/json/'+str(i)+'_match.json')
        req = Request('https://www.prokabaddi.com/sifeeds/kabaddi/live/json/'+str(i)+'_match.json', headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'})
        elevations = urlopen(req).read()
        #elevations = response.read()
        data = json.loads(elevations)
        match_data_cmb = match_data_cmb.append({'row_id': i, 'match_id': data['match_detail']['match_id'],
                                            'match_number': data['match_detail']['match_number'],
                                            'date': data['match_detail']['date'],
                                            'start_time': data['match_detail']['start_time'],
                                            
                                            'result_outcome': data['match_detail']['result']['outcome'] if data['match_detail']['result'] else None,
                                            'result_value': data['match_detail']['result']['value'] if data['match_detail']['result'] else None,
                                            'winning_team' : data['match_detail']['result']['winning_team'] if data['match_detail']['result'] else None,
                                                
                                            'player_of_the_match_id' : data['match_detail']['player_of_the_match'] if data['match_detail']['player_of_the_match'] else None,
                                            'player_of_the_match_name'  :  data['match_detail']['player_of_the_match'][0]['value'] if data['match_detail']['player_of_the_match'] else None,
                                            'series_id' : data['match_detail']['series']['id'],
                                            'status_id' : data['match_detail']['status_id'],
                                            'status' : data['match_detail']['status'],
                                            'toss_winner'  : data['match_detail']['toss']['winner'],
                                            'toss_selection' : data['match_detail']['toss']['selection'],
                                            'venue_id'  : data['match_detail']['venue']['id'],
                                            'venue_name'  : data['match_detail']['venue']['name']                                           
                                           },ignore_index=True)
        
        total_teams = 2
        for i in range(total_teams):
            squad_size = len(data['teams']['team'][i]['squad'])
            team_stats = team_stats.append({
                'match_id': data['match_detail']['match_id'],
                'match_number': data['match_detail']['match_number'],
                'team_id' : data['teams']['team'][i]['id'],
                'team_name' : data['teams']['team'][i]['name'],
                'team_score': data['teams']['team'][i]['score'],
                'Team_points_total' : data['teams']['team'][i]['stats']['points']['total'],
                'Team_points_all_out' : data['teams']['team'][i]['stats']['points']['all_out'],
                'Team_points_extras' : data['teams']['team'][i]['stats']['points']['extras'],
                'Team_points_declare' : data['teams']['team'][i]['stats']['points']['declare'],
                'Team_points_raid_points_total' : data['teams']['team'][i]['stats']['points']['raid_points']['total'],
                'Team_points_raid_points_touch' : data['teams']['team'][i]['stats']['points']['raid_points']['touch'],
                'Team_points_raid_points_raid_bonus' : data['teams']['team'][i]['stats']['points']['raid_points']['raid_bonus'],
                'Team_points_tackle_points_total' : data['teams']['team'][i]['stats']['points']['tackle_points']['total'],
                'Team_points_tackle_points_capture': data['teams']['team'][i]['stats']['points']['tackle_points']['capture'],
                'Team_points_tackle_points_capture_bonus' : data['teams']['team'][i]['stats']['points']['tackle_points']['capture_bonus'],
                'Team_raids_total' : data['teams']['team'][i]['stats']['raids']['total'],
                'Team_raids_successful' : data['teams']['team'][i]['stats']['raids']['successful'],
                'Team_raids_unsuccessful' : data['teams']['team'][i]['stats']['raids']['unsuccessful'],
                'Team_raids_Empty' : data['teams']['team'][i]['stats']['raids']['Empty'],
                'Team_tackles_total' : data['teams']['team'][i]['stats']['tackles']['total'],
                'Team_tackles_successful' : data['teams']['team'][i]['stats']['tackles']['successful'],
                'Team_tackles_unsuccessful' : data['teams']['team'][i]['stats']['tackles']['unsuccessful'],
                'Team_all_outs' : data['teams']['team'][i]['stats']['all_outs'],
                'Team_declare' : data['teams']['team'][i]['stats']['declare'] },ignore_index=True )
            
            for j in range(squad_size):
                squad_details = squad_details.append(
                    {#'home_team_id' : data['teams']['home_team_id'] if data['teams']['home_team_id'] else None ,
                     #'home_team_name' : data['teams']['home_team_name'] if data['teams']['home_team_name'] else None ,
                     'match_id': data['match_detail']['match_id'],
                     'match_number': data['match_detail']['match_number'],
                     'team_id' : data['teams']['team'][i]['id'],
                     'team_name' : data['teams']['team'][i]['name'],
                     'team_score': data['teams']['team'][i]['score'],
                     'team_squad_id' : data['teams']['team'][i]['squad'][j]['id'],
                     'team_squad_name' : data['teams']['team'][i]['squad'][j]['name'],
                     'team_squad_skill' : data['teams']['team'][i]['squad'][j]['skill'],
                     'team_squad_role' : data['teams']['team'][i]['squad'][j]['role'],
                     'team_squad_red_card' : data['teams']['team'][i]['squad'][j]['red_card'],
                     'team_squad_yellow_card' : data['teams']['team'][i]['squad'][j]['yellow_card'],
                     'team_squad_green_card' : data['teams']['team'][i]['squad'][j]['green_card'],
                     'team_squad_green_jersey' : data['teams']['team'][i]['squad'][j]['jersey'],
                     'team_squad_green_played' : data['teams']['team'][i]['squad'][j]['played'],
                     'team_squad_green_captain' : data['teams']['team'][i]['squad'][j]['captain'],
                     'team_squad_green_on_court' : data['teams']['team'][i]['squad'][j]['on_court'],
                     'team_squad_green_starter' : data['teams']['team'][i]['squad'][j]['starter'],
                     'team_squad_green_top_raider' : data['teams']['team'][i]['squad'][j]['top_raider'],
                     'total_points' : data['teams']['team'][i]['squad'][j]['points']['total'],
                     'total_raid_points_total' : data['teams']['team'][i]['squad'][j]['points']['raid_points']['total'],
                     'total_raid_points_touch' : data['teams']['team'][i]['squad'][j]['points']['raid_points']['touch'],
                     'total_raid_points_raid_bonus' : data['teams']['team'][i]['squad'][j]['points']['raid_points']['raid_bonus'],
                     'total_tackle_points_total' : data['teams']['team'][i]['squad'][j]['points']['tackle_points']['total'],
                     'total_tackle_points_capture' : data['teams']['team'][i]['squad'][j]['points']['tackle_points']['capture'],
                     'total_tackle_points_capture_bonus' : data['teams']['team'][i]['squad'][j]['points']['tackle_points']['capture_bonus'],
                     'raids_total' : data['teams']['team'][i]['squad'][j]['raids']['total'],
                     'raids_successful' : data['teams']['team'][i]['squad'][j]['raids']['successful'],
                     'raids_unsuccessful' : data['teams']['team'][i]['squad'][j]['raids']['unsuccessful'],
                     'raids_Empty' : data['teams']['team'][i]['squad'][j]['raids']['Empty'],
                     'tackles_total' : data['teams']['team'][i]['squad'][j]['tackles']['total'],
                     'tackles_successful' : data['teams']['team'][i]['squad'][j]['tackles']['successful'],
                     'tackles_unsuccessful' : data['teams']['team'][i]['squad'][j]['tackles']['unsuccessful']},ignore_index=True)


        #print("Data added successfully")
        Total_Matches +=1
        
    except urllib.error.HTTPError as err:
        print(err.code)
print("Total Data available for {} matches".format(Total_Matches))
# Out:
#           date  match_id match_number  \
# 0    7/26/2014       1.0      Match 1
# 1    7/26/2014       2.0      Match 2
# 2    7/27/2014       3.0      Match 3
# 3    7/27/2014       4.0      Match 4
# 4    7/28/2014       5.0      Match 5
# 5    7/28/2014       6.0      Match 6
# 6    7/29/2014       7.0      Match 7
# 7    7/30/2014       8.0      Match 8
# 8    7/31/2014       9.0      Match 9
# 9    7/31/2014      10.0     Match 10
# 10    8/1/2014      11.0     Match 11
# 11    8/1/2014      12.0     Match 12
# 12    8/2/2014      13.0     Match 13
# 13    8/2/2014      14.0     Match 14
# 14    8/3/2014      15.0     Match 15
# 15    8/3/2014      16.0     Match 16
# 16    8/4/2014      17.0     Match 17
# 17    8/4/2014      18.0     Match 18
# 18    8/5/2014      19.0     Match 19
# 19    8/5/2014      20.0     Match 20
# 20    8/6/2014      21.0     Match 21
# 21    8/7/2014      22.0     Match 22
# 22    8/8/2014      23.0     Match 23
# ...
